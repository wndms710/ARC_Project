# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Data

# %%
t_dataset = pd.read_csv("T_data_.csv")
t_dataset
# Out:
#       nSub  nARC  thARC    T_mean      T_SD
# 0      1.0   2.0    0.0  0.999999  0.000002
# 1      1.0   1.0    0.0  0.999999  0.000002
# 2      1.0   1.0    0.2  0.999999  0.000003
# 3      1.0   1.0    0.4  0.999999  0.000003
# 4      1.0   1.0    0.6  1.000000  0.000002
# ...    ...   ...    ...       ...       ...
# 1501   5.0   5.0    0.2  0.555554  0.000005
# 1502   5.0   5.0    0.4  0.555533  0.000059
# 1503   5.0   5.0    0.6  0.554505  0.001815
# 1504   5.0   5.0    0.8  0.555558  0.000040
# 1505   5.0   5.0    1.0  0.555537  0.000146
#
# [1506 rows x 5 columns]

# %%
t_dataset.isnull().sum()
# Out:
# nSub      0
# nARC      0
# thARC     0
# T_mean    0
# T_SD      0
# dtype: int64

# %%
x_data = t_dataset.drop("T_mean", axis = 1, inplace = False)
x_data = x_data.drop("T_SD", axis = 1, inplace = False)

y_data = t_dataset.drop("nSub", axis = 1, inplace = False)
y_data = y_data.drop("nARC", axis = 1, inplace = False)
y_data = y_data.drop("thARC", axis = 1, inplace = False)

y_data
# Out:
#         T_mean      T_SD
# 0     0.999999  0.000002
# 1     0.999999  0.000002
# 2     0.999999  0.000003
# 3     0.999999  0.000003
# 4     1.000000  0.000002
# ...        ...       ...
# 1501  0.555554  0.000005
# 1502  0.555533  0.000059
# 1503  0.554505  0.001815
# 1504  0.555558  0.000040
# 1505  0.555537  0.000146
#
# [1506 rows x 2 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 1)

# %%
print('t_train_x',x_train.shape)
print('t_train_y',y_train.shape)
print('t_test_x',x_test.shape)
print('t_test_y',y_test.shape)
# Out:
# t_train_x (1054, 3)
# t_train_y (1054, 2)
# t_test_x (452, 3)
# t_test_y (452, 2)

# %%
# Loss function
def MSE(real, predict):
    error = ((real-predict)**2).mean()
    
    return error

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Model

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

reg_pred = reg.predict(x_test)

# 모델 평가
mse = MSE(y_test, reg_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(reg.score(x_train, y_train))
print(reg.score(x_test, y_test))
plt.scatter(y_test,reg_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017143
# T_SD      0.000694
# dtype: float64
# 0.34113980879170364
# 0.3114001541483711

# %% [markdown]
# # Ridge

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.01)
ridge.fit(x_train, y_train)

ridge_pred = ridge.predict(x_test)

# 모델 평가
mse = MSE(y_test, ridge_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(ridge.score(x_train, y_train))
print(ridge.score(x_test, y_test))
plt.scatter(y_test,ridge_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017143
# T_SD      0.000694
# dtype: float64
# 0.3411398082282827
# 0.3114012259256964

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(alpha):
    
    ridge_final = Ridge(alpha=alpha)
    ridge_final.fit(x_train, y_train)
    
   # Validation
    y_pred = ridge_final.predict(x_test)
    acc= ridge_final.score(x_test, y_test)
    
    return acc

pbounds = {'alpha': (0.1, 10)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target
# | 75        | 0.3118    | 7.211     |
# | 76        | 0.3118    | 7.236     |
# | 77        | 0.3118    | 7.208     |
# | 78        | 0.3118    | 7.236     |
# | 79        | 0.3118    | 7.208     |
# | 80        | 0.3118    | 7.238     |
# | 81        | 0.3118    | 7.206     |
# | 82        | 0.3118    | 7.239     |
# | 83        | 0.3118    | 7.207     |
# | 84        | 0.3118    | 7.239     |
# | 85        | 0.3118    | 7.238     |
# | 86        | 0.3118    | 7.205     |
# | 87        | 0.3118    | 7.239     |
# | 88        | 0.3118    | 7.206     |
# | 89        | 0.3118    | 7.239     |
# | 90        | 0.3118    | 7.206     |
# | 91        | 0.3118    | 7.24      |
# | 92        | 0.3118    | 7.207     |
# | 93        | 0.3118    | 7.24      |
# | 94        | 0.3118    | 7.205     |
# | 95        | 0.3118    | 7.24      |
# | 96        | 0.3118    | 7.207     |
# | 97        | 0.3118    | 7.24      |
# | 98        | 0.3118    | 7.208     |
# | 99        | 0.3118    | 7.242     |
# | 100       | 0.3118    | 7.208     |
# | 101       | 0.3118    | 7.24      |
# | 102       | 0.3118    | 7.207     |
# | 103       | 0.3118    | 7.24      |
# | 104       | 0.3118    | 7.208     |
# | 105       | 0.3118    | 7.209     |
# =====================================

# %%
from sklearn.linear_model import Ridge

ridge_final = Ridge(alpha=7.224)
ridge_final.fit(x_train, y_train)

ridge_final_pred = ridge_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, ridge_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(ridge_final.score(x_train, y_train))
print(ridge_final.score(x_test, y_test))
plt.scatter(y_test,ridge_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017142
# T_SD      0.000693
# dtype: float64
# 0.3408774052393511
# 0.3117654439811434

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Model

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)

dt_pred = dt.predict(x_test)

# 모델 평가
mse = MSE(y_test, dt_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(dt.score(x_train, y_train))
print(dt.score(x_test, y_test))
plt.scatter(y_test,dt_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.000583
# T_SD      0.000074
# dtype: float64
# 1.0
# 0.9513386866290634

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Model

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

rf_pred = rf.predict(x_test)
# 모델 평가
mse = MSE(y_test, rf_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(rf.score(x_train, y_train))
print(rf.score(x_test, y_test))
plt.scatter(y_test,rf_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.000205
# T_SD      0.000020
# dtype: float64
# 0.9963614467864625
# 0.9860269076865498

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(n_estimators):
    
    rf_final = RandomForestRegressor(n_estimators=int(n_estimators), random_state=42)
    rf_final.fit(x_train, y_train)
    
   # Validation
    y_pred = rf_final.predict(x_test)
    acc= rf_final.score(x_test, y_test)
    
    return acc

pbounds = {'n_estimators': (10, 500)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target
# | 82        | 0.9862    | 89.74     |
# | 83        | 0.9862    | 89.78     |
# | 84        | 0.9862    | 89.71     |
# | 85        | 0.9862    | 89.74     |
# | 86        | 0.9862    | 89.7      |
# | 87        | 0.9862    | 89.82     |
# | 88        | 0.9862    | 89.75     |
# | 89        | 0.9862    | 89.8      |
# | 90        | 0.9862    | 89.72     |
# | 91        | 0.9862    | 89.71     |
# | 92        | 0.9862    | 89.79     |
# | 93        | 0.9862    | 89.76     |
# | 94        | 0.9862    | 89.71     |
# | 95        | 0.9862    | 89.69     |
# | 96        | 0.9862    | 89.79     |
# | 97        | 0.9862    | 89.76     |
# | 98        | 0.9862    | 89.79     |
# | 99        | 0.9862    | 89.7      |
# | 100       | 0.9862    | 89.76     |
# | 101       | 0.9862    | 89.74     |
# | 102       | 0.9862    | 89.72     |
# | 103       | 0.9862    | 89.7      |
# | 104       | 0.9862    | 89.73     |
# | 105       | 0.9862    | 89.76     |
# =====================================

# %%
rf_final = RandomForestRegressor(n_estimators=89, random_state=42)
rf_final.fit(x_train, y_train)

rf_final_pred = rf_final.predict(x_test)
# 모델 평가
mse = MSE(y_test, rf_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(rf_final.score(x_train, y_train))
print(rf_final.score(x_test, y_test))
plt.scatter(y_test,rf_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.00020
# T_SD      0.00002
# dtype: float64
# 0.996412359980736
# 0.9862493069900307

# %%
rf_final.predict([[3.4, 1.8, 0.5]])
# Out:
# array([[0.73415785, 0.01261575]])

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# ## Model

# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor

svr = MultiOutputRegressor(SVR(kernel='rbf', gamma=0.1, C=0.1))
svr.fit(x_train, y_train)

svr_pred = svr.predict(x_test)
# 모델 평가
mse = MSE(y_test, svr_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(svr.score(x_train, y_train))
print(svr.score(x_test, y_test))
plt.scatter(y_test,svr_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.009517
# T_SD      0.005670
# dtype: float64
# -1.1929878176233082
# -2.029202992906838

# %% [markdown]
# ## Optimize

# %%
def train_acc(gamma, C):
    
    svr_final = MultiOutputRegressor(SVR(kernel='rbf', gamma=gamma, C=C))
    svr_final.fit(x_train, y_train)
    
   # Validation
    y_pred = svr_final.predict(x_test)
    acc= svr_final.score(x_test, y_test)
    
    return acc

pbounds = {'gamma': (0.1, 10), 'C': (0.1, 10)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   |     C     |   gamma   |
# -------------------------------------------------
# | 1         | -2.806    | 4.229     | 7.231     |
# | 2         | -2.741    | 0.1011    | 3.093     |
# | 3         | -2.566    | 1.553     | 1.014     |
# | 4         | -2.728    | 1.944     | 3.521     |
# | 5         | -2.776    | 4.028     | 5.434     |
# | 6         | -0.3652   | 2.958     | 0.1       |
# | 7         | -2.797    | 8.317     | 6.635     |
# | 8         | -2.792    | 1.578     | 6.325     |
# | 9         | -2.81     | 0.9521    | 7.611     |
# | 10        | -0.3968   | 3.381     | 0.1       |
# | 11        | -0.4188   | 5.485     | 0.1       |
# | 12        | -0.4133   | 7.563     | 0.1       |
# | 13        | -2.655    | 6.86      | 1.939     |
# | 71        | -0.8606   | 2.361     | 0.1308    |
# | 72        | -2.177    | 2.456     | 0.3805    |
# | 73        | -0.7771   | 2.017     | 0.1264    |
# | 74        | -1.911    | 1.801     | 0.268     |
# | 75        | -0.3309   | 2.181     | 0.1       |
# | 76        | -2.81     | 2.703     | 7.568     |
# | 77        | -1.92     | 2.197     | 0.2703    |
# | 78        | -2.796    | 6.268     | 6.575     |
# | 79        | -2.779    | 3.595     | 5.473     |
# | 80        | -2.761    | 7.034     | 4.731     |
# | 81        | -2.713    | 3.746     | 3.101     |
# | 82        | -2.793    | 9.98      | 6.367     |
# | 83        | -2.811    | 8.044     | 7.768     |
# | 84        | -2.777    | 6.84      | 5.337     |
# | 85        | -2.836    | 8.306     | 9.852     |
# | 86        | -2.817    | 5.704     | 8.251     |
# | 87        | -2.724    | 9.939     | 3.458     |
# | 88        | -2.829    | 1.434     | 9.141     |
# | 89        | -0.5315   | 6.777     | 0.1063    |
# | 90        | -2.829    | 4.428     | 9.115     |
# | 91        | -2.029    | 0.1       | 0.1       |
# | 92        | -2.769    | 2.232     | 4.957     |
# | 93        | -1.451    | 7.881     | 0.1949    |
# | 94        | -0.504    | 8.064     | 0.1056    |
# | 95        | -2.723    | 8.441     | 3.385     |
# | 96        | -2.733    | 0.9485    | 3.634     |
# | 97        | -2.685    | 1.329     | 2.45      |
# | 98        | -2.658    | 5.477     | 1.953     |
# | 99        | -2.801    | 3.683     | 6.812     |
# | 100       | -2.807    | 0.1       | 6.552     |
# | 101       | -2.812    | 9.982     | 7.839     |
# | 102       | -2.828    | 0.1246    | 8.573     |
# | 103       | -2.838    | 7.048     | 10.0      |
# | 104       | -2.791    | 5.079     | 6.21      |
# | 105       | -2.747    | 3.247     | 4.2       |
# =================================================

# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor

svr_final = MultiOutputRegressor(SVR(kernel='rbf', gamma=0.04943, C=3.237))
svr_final.fit(x_train, y_train)

svr_final_pred = svr_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, svr_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(svr_final.score(x_train, y_train))
print(svr_final.score(x_test, y_test))
plt.scatter(y_test,svr_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.006821
# T_SD      0.001405
# dtype: float64
# 0.3289839295922876
# 0.16074319760105266

# %% [markdown]
# # Neural Networks

# %% [markdown]
# ## Model

# %%
import tensorflow as tf

# 다중 출력을 다루는 신경망 모델 정의
nn = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
])

# 모델 컴파일
nn.compile(optimizer='adam', loss='mean_squared_error')

# 모델 훈련
nn.fit(x_train, y_train, epochs=50, batch_size=16, validation_split=0.2)

nn_pred = nn.predict(x_test)

# 모델 평가
mse = MSE(y_test, nn_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

# 작을 수록 더 좋음
print(nn.evaluate(x_train, y_train))
print(nn.evaluate(x_test, y_test))

plt.scatter(y_test,nn_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# 2023-12-08 18:08:21.081126: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 53/53 [==============================] - 1s 6ms/step - loss: 0.0668 - val_loss: 0.0371
# Epoch 2/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0212
# Epoch 3/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0135
# Epoch 4/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0081
# Epoch 5/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 6/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 7/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 8/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 9/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 10/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 11/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 12/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 13/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 14/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 15/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 16/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 17/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 18/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 19/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 20/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 21/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 22/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 23/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 24/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 25/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 26/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 27/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 28/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 29/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 30/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 31/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 32/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 33/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 34/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 35/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 36/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 37/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 38/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 39/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 40/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 41/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 42/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 43/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 44/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 45/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 46/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 47/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 48/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 49/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 50/50
# 53/53 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0018
# 15/15 [==============================] - 0s 2ms/step
# Mean Squared Error: T_mean    0.001957
# T_SD      0.000324
# dtype: float64
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0014
# 0.0013988424325361848
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0011
# 0.0011402752716094255

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(epochs, batch_size):
    
    # 다중 출력을 다루는 신경망 모델 정의
    nn_final = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
    ])

    # 모델 컴파일
    nn_final.compile(optimizer='adam', loss='mean_squared_error')

    # 모델 훈련
    nn_final.fit(x_train, y_train, epochs=int(epochs), batch_size=int(batch_size), validation_split=0.2, verbose=0)
    
   # Validation
    nn_final_pred = nn_final.predict(x_test)
    acc= nn_final.evaluate(x_test, y_test)
    
    return -acc

pbounds = {'epochs': (10, 100), 'batch_size': (10, 100)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   | batch_... |  epochs   |
# -------------------------------------------------
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0014
# | 1         | -0.001438 | 47.53     | 74.83     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018
# | 2         | -0.001789 | 10.01     | 37.21     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0041
# | 3         | -0.004138 | 23.21     | 18.31     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011
# | 4         | -0.001081 | 26.76     | 41.1      |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0022
# | 5         | -0.002167 | 45.71     | 58.49     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0014
# | 6         | -0.001446 | 26.14     | 42.26     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0019
# | 7         | -0.001864 | 30.52     | 36.71     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0033
# | 8         | -0.003325 | 24.25     | 37.03     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0019
# | 9         | -0.001932 | 29.11     | 41.45     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018
# | 10        | -0.001832 | 44.74     | 73.66     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0017
# | 11        | -0.001748 | 48.8      | 71.69     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0010
# | 12        | -0.001021 | 49.73     | 77.17     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016
# | 13        | -0.001623 | 46.89     | 78.76     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0034
# | 14        | -0.003354 | 51.68     | 75.23     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0013
# | 15        | -0.001342 | 48.3      | 77.28     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016
# | 16        | -0.00159  | 49.64     | 79.47     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0013
# | 17        | -0.001341 | 45.07     | 76.48     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0017
# | 18        | -0.001664 | 42.09     | 76.45     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0012
# | 19        | -0.001186 | 43.26     | 79.18     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 9.1042e-04
# | 20        | -0.000910 | 43.25     | 81.71     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0015
# | 21        | -0.001545 | 41.38     | 81.2      |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016
# | 22        | -0.00157  | 45.69     | 82.59     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0013
# | 23        | -0.001325 | 42.23     | 83.61     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0015
# | 24        | -0.001544 | 44.17     | 86.45     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 8.2376e-04
# | 25        | -0.000823 | 40.06     | 87.24     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0015
# | 26        | -0.001507 | 41.29     | 89.17     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 9.7160e-04
# | 27        | -0.000971 | 38.15     | 86.98     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0012
# | 28        | -0.001185 | 39.27     | 85.02     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.
|
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011
# | 77        | -0.001098 | 22.31     | 65.75     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 8.3335e-04
# | 78        | -0.000833 | 22.37     | 72.46     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011
# | 79        | -0.001057 | 25.38     | 69.73     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0010
# | 80        | -0.001036 | 19.44     | 71.32     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011
# | 81        | -0.001112 | 15.24     | 58.72     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018
# | 82        | -0.00183  | 22.19     | 56.09     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 8.1518e-04
# | 83        | -0.000815 | 10.33     | 72.16     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0090
# | 84        | -0.008965 | 79.78     | 17.41     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018
# | 85        | -0.001806 | 99.24     | 99.86     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0050
# | 86        | -0.00495  | 99.99     | 59.9      |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0015
# | 87        | -0.001506 | 72.51     | 99.05     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0028
# | 88        | -0.002829 | 71.35     | 48.18     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0282
# | 89        | -0.02821  | 49.55     | 10.08     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0026
# | 90        | -0.002588 | 85.18     | 84.36     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0031
# | 91        | -0.003143 | 99.74     | 34.35     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0030
# | 92        | -0.003025 | 10.0      | 10.0      |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0033
# | 93        | -0.003297 | 54.25     | 41.98     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0029
# | 94        | -0.002945 | 78.54     | 66.18     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0222
# | 95        | -0.02216  | 99.82     | 10.49     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0014
# | 96        | -0.001439 | 99.41     | 82.55     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016
# | 97        | -0.001564 | 58.63     | 99.81     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016
# | 98        | -0.001591 | 85.89     | 99.68     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032
# | 99        | -0.003199 | 86.92     | 44.2      |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 9.5139e-04
# | 100       | -0.000951 | 10.0      | 48.66     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011
# | 101       | -0.001063 | 69.54     | 86.64     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0022
# | 102       | -0.002206 | 59.96     | 56.43     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0028
# | 103       | -0.002764 | 68.79     | 34.18     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0017
# | 104       | -0.001729 | 10.0      | 24.15     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0021
# | 105       | -0.002109 | 91.94     | 72.77     |
# =================================================

# %%
# 다중 출력을 다루는 신경망 모델 정의
nn_final = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
])

# 모델 컴파일
nn_final.compile(optimizer='adam', loss='mean_squared_error')

# 모델 훈련
nn_final.fit(x_train, y_train, epochs=77, batch_size=15, validation_split=0.2)

nn_final_pred = nn_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, nn_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

# 작을 수록 더 좋음
print(nn_final.evaluate(x_train, y_train))
print(nn_final.evaluate(x_test, y_test))

plt.scatter(y_test,nn_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Epoch 1/77
# 57/57 [==============================] - 1s 5ms/step - loss: 0.0479 - val_loss: 0.0288
# Epoch 2/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0196
# Epoch 3/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0120
# Epoch 4/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 5/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 6/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 7/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 8/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 9/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 10/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 11/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 12/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 13/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 14/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 15/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 16/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 17/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 18/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 19/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 20/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 21/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 22/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 23/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 24/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 25/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 26/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 27/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 28/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 29/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 30/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 31/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 32/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 33/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 34/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 35/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 36/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 37/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 38/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 39/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 40/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 41/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 42/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 43/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 44/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 45/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 46/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 47/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 48/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 49/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 50/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 51/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 52/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 53/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 54/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 55/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 56/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 57/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 58/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 59/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 60/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 61/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 62/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 63/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 64/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 65/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 66/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 67/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 68/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 69/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 70/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 71/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 72/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.9243e-04 - val_loss: 0.0012
# Epoch 73/77
# 57/57 [==============================] - 0s 2ms/step - loss: 8.3877e-04 - val_loss: 0.0012
# Epoch 74/77
# 57/57 [==============================] - 0s 3ms/step - loss: 9.6106e-04 - val_loss: 0.0011
# Epoch 75/77
# 57/57 [==============================] - 0s 3ms/step - loss: 9.8897e-04 - val_loss: 0.0012
# Epoch 76/77
# 57/57 [==============================] - 0s 3ms/step - loss: 8.4885e-04 - val_loss: 0.0013
# Epoch 77/77
# 57/57 [==============================] - 0s 3ms/step - loss: 9.7652e-04 - val_loss: 0.0013
# 15/15 [==============================] - 0s 1ms/step
# Mean Squared Error: T_mean    0.001464
# T_SD      0.000290
# dtype: float64
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0010
# 0.0010161062236875296
# 15/15 [==============================] - 0s 1ms/step - loss: 8.7697e-04
# 0.0008769663982093334

# %% [markdown]
# # Reverse trace (Bayesian Optimization)

# %%
x_data = t_dataset.drop("T_mean", axis = 1, inplace = False)
x_data = x_data.drop("T_SD", axis = 1, inplace = False)

y_data = t_dataset["T_mean"]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 1)

# %%
from bayes_opt import BayesianOptimization

def train_acc(n_estimators):
    
    rf_final = RandomForestRegressor(n_estimators=int(n_estimators), random_state=42)
    rf_final.fit(x_train, y_train)
    
   # Validation
    y_pred = rf_final.predict(x_test)
    acc= rf_final.score(x_test, y_test)
    
    return acc

pbounds = {'n_estimators': (10, 500)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   | n_esti... |
# -------------------------------------
# | 1         | 0.9914    | 214.3     |
# | 2         | 0.9917    | 363.0     |
# | 3         | 0.9839    | 10.06     |
# | 4         | 0.9913    | 158.1     |
# | 5         | 0.9917    | 81.91     |
# | 6         | 0.9917    | 80.16     |
# | 7         | 0.9916    | 294.1     |
# | 8         | 0.9917    | 435.3     |
# | 9         | 0.9918    | 500.0     |
# | 10        | 0.9915    | 254.8     |
# | 11        | 0.9917    | 399.1     |
# | 12        | 0.9918    | 469.4     |
# | 13        | 0.9917    | 328.7     |
# | 14        | 0.9912    | 124.8     |
# | 15        | 0.9914    | 187.1     |
# | 16        | 0.9917    | 485.7     |
# | 17        | 0.9917    | 381.0     |
# | 18        | 0.9917    | 452.3     |
# | 19        | 0.9915    | 274.7     |
# | 20        | 0.9917    | 417.5     |
# | 21        | 0.9916    | 345.3     |
# | 22        | 0.9916    | 312.1     |
# | 23        | 0.9914    | 235.6     |
# | 24        | 0.9918    | 475.8     |
# | 25        | 0.9918    | 496.3     |
# | 26        | 0.9917    | 463.4     |
# | 27        | 0.9918    | 472.0     |
# | 28        | 0.9918    | 500.0     |
# | 29        | 0.9918    | 500.0     |
# | 30        | 0.9918    | 499.9     |
# | 31        | 0.9918    | 500.0     |
# | 32        | 0.9918    | 499.1     |
# | 33        | 0.9918    | 500.0     |
# | 34        | 0.9918    | 499.1     |
# | 35        | 0.9918    | 499.9     |
# | 36        | 0.9918    | 499.1     |
# | 37        | 0.9918    | 500.0     |
# | 38        | 0.9918    | 499.1     |
final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: 0.00020692649086189629
# 0.9977700908228802
# 0.9917646430958778

# %%
rf_final.predict([[3.4, 1.8, 3]])
# Out:
# array([0.8758301])

# %%
from bayes_opt import BayesianOptimization

nSub = 3.4
nARC = 1.8
# thARC = 0.5

def train_acc(thARC):
    rf_final = RandomForestRegressor(n_estimators=500, random_state=42)
    rf_final.fit(x_train, y_train)
   # Validation
    T_pred = rf_final.predict([[nSub, nARC, thARC]])

    return T_pred[0]

pbounds = {'thARC': (0, 3.0)} # 범위 설정
# pbounds = {'nARC': (1.0, 2.0)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1,
    allow_duplicate_points=True)

optimizer.maximize(init_points=5 , n_iter= 50)
# Out:
# |   iter    |  target   |   thARC   |
# -------------------------------------
# | 1         | 0.8758    | 1.251     |
# | 2         | 0.8758    | 2.161     |
# | 3         | 0.6916    | 0.0003431 |
# | 4         | 0.8758    | 0.907     |
# | 5         | 0.7324    | 0.4403    |
# | 6         | 0.8758    | 2.966     |
# | 7         | 0.8758    | 2.567     |
# | 8         | 0.8758    | 1.251     |
# | 9         | 0.8758    | 1.731     |
# | 10        | 0.8758    | 1.941     |
# | 11        | 0.8758    | 1.064     |
# | 12        | 0.8758    | 2.779     |
# | 13        | 0.8758    | 1.489     |
# | 14        | 0.8758    | 2.364     |
# | 15        | 0.8758    | 1.371     |
# | 16        | 0.8758    | 0.9742    |
# | 17        | 0.8758    | 1.617     |
# | 18        | 0.8758    | 2.882     |
# | 19        | 0.8758    | 2.052     |
# | 20        | 0.8758    | 2.465     |
# | 21        | 0.8758    | 1.836     |
# | 22        | 0.8758    | 2.673     |
# | 23        | 0.8758    | 2.262     |
# | 24        | 0.8758    | 1.158     |
# | 25        | 0.8758    | 3.0       |
# | 26        | 0.8758    | 1.553     |
# | 27        | 0.8758    | 1.312     |
# | 28        | 0.8758    | 1.996     |
# | 29        | 0.8758    | 0.9356    |
# | 30        | 0.8758    | 2.62      |
# | 31        | 0.8758    | 1.677     |
# | 32        | 0.8758    | 1.43      |
# | 33        | 0.8758    | 2.313     |
# | 34        | 0.8758    | 2.109     |
# | 35        | 0.8758    | 2.83      |
# | 36        | 0.8758    | 1.886     |
# | 37        | 0.8758    | 2.514     |
# | 38        | 0.8758    | 2.726     |
# | 39        | 0.8758    | 1.783     |
# | 40        | 0.8758    | 1.111     |
# | 41        | 0.8758    | 2.414     |
# | 42        | 0.8758    | 2.211     |
# | 43        | 0.8758    | 1.204     |
# | 44        | 0.8758    | 1.02      |
# | 45        | 0.8758    | 2.924     |
# | 46        | 0.8758    | 1.585     |
# | 47        | 0.8758    | 1.522     |
# | 48        | 0.8758    | 1.4       |
# | 49        | 0.8758    | 1.342     |
# | 50        | 0.8758    | 1.647     |
# | 51        | 0.8758    | 0.9254    |
# | 52        | 0.8758    | 1.46      |
# | 53        | 0.8758    | 2.08      |
# | 54        | 0.8758    | 1.284     |
# | 55        | 0.8758    | 1.914     |
# =====================================
