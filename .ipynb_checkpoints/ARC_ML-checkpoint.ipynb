# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data

# %%
t_dataset = pd.read_csv("T_data_.csv")
t_dataset
# Out:
#       nSub  nARC  thARC    T_mean      T_SD
# 0      1.0   2.0    0.0  0.999999  0.000002
# 1      1.0   1.0    0.0  0.999999  0.000002
# 2      1.0   1.0    0.2  0.999999  0.000003
# 3      1.0   1.0    0.4  0.999999  0.000003
# 4      1.0   1.0    0.6  1.000000  0.000002
# ...    ...   ...    ...       ...       ...
# 1501   5.0   5.0    0.2  0.555554  0.000005
# 1502   5.0   5.0    0.4  0.555533  0.000059
# 1503   5.0   5.0    0.6  0.554505  0.001815
# 1504   5.0   5.0    0.8  0.555558  0.000040
# 1505   5.0   5.0    1.0  0.555537  0.000146
#
# [1506 rows x 5 columns]

# %%
t_dataset.isnull().sum()
# Out:
# nSub      0
# nARC      0
# thARC     0
# T_mean    0
# T_SD      0
# dtype: int64

# %%
x_data = t_dataset.drop("T_mean", axis = 1, inplace = False)
x_data = x_data.drop("T_SD", axis = 1, inplace = False)

y_data = t_dataset.drop("nSub", axis = 1, inplace = False)
y_data = y_data.drop("nARC", axis = 1, inplace = False)
y_data = y_data.drop("thARC", axis = 1, inplace = False)

y_data
# Out:
#         T_mean      T_SD
# 0     0.999999  0.000002
# 1     0.999999  0.000002
# 2     0.999999  0.000003
# 3     0.999999  0.000003
# 4     1.000000  0.000002
# ...        ...       ...
# 1501  0.555554  0.000005
# 1502  0.555533  0.000059
# 1503  0.554505  0.001815
# 1504  0.555558  0.000040
# 1505  0.555537  0.000146
#
# [1506 rows x 2 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 1)

# %%
print('t_train_x',x_train.shape)
print('t_train_y',y_train.shape)
print('t_test_x',x_test.shape)
print('t_test_y',y_test.shape)
# Out:
# t_train_x (1054, 3)
# t_train_y (1054, 2)
# t_test_x (452, 3)
# t_test_y (452, 2)

# %%
# Loss function
def MSE(real, predict):
    error = ((real-predict)**2).mean()
    
    return error

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Model

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

reg_pred = reg.predict(x_test)

# 모델 평가
mse = MSE(y_test, reg_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(reg.score(x_train, y_train))
print(reg.score(x_test, y_test))
plt.scatter(y_test,reg_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017143
# T_SD      0.000694
# dtype: float64
# 0.3411398087917033
# 0.31140015414837113

# %% [markdown]
# # Ridge

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.01)
ridge.fit(x_train, y_train)

ridge_pred = ridge.predict(x_test)

# 모델 평가
mse = MSE(y_test, ridge_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(ridge.score(x_train, y_train))
print(ridge.score(x_test, y_test))
plt.scatter(y_test,ridge_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017143
# T_SD      0.000694
# dtype: float64
# 0.3411398082282827
# 0.3114012259256964

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(alpha):
    
    ridge_final = Ridge(alpha=alpha)
    ridge_final.fit(x_train, y_train)
    
   # Validation
    y_pred = ridge_final.predict(x_test)
    acc= ridge_final.score(x_test, y_test)
    
    return acc

pbounds = {'alpha': (0.1, 10)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target
# | 87        | 0.3118    | 7.239     |
# | 88        | 0.3118    | 7.206     |
# | 89        | 0.3118    | 7.239     |
# | 90        | 0.3118    | 7.206     |
# | 91        | 0.3118    | 7.24      |
# | 92        | 0.3118    | 7.207     |
# | 93        | 0.3118    | 7.24      |
# | 94        | 0.3118    | 7.205     |
# | 95        | 0.3118    | 7.24      |
# | 96        | 0.3118    | 7.207     |
# | 97        | 0.3118    | 7.24      |
# | 98        | 0.3118    | 7.208     |
# | 99        | 0.3118    | 7.242     |
# | 100       | 0.3118    | 7.208     |
# | 101       | 0.3118    | 7.24      |
# | 102       | 0.3118    | 7.207     |
# | 103       | 0.3118    | 7.24      |
# | 104       | 0.3118    | 7.208     |
# | 105       | 0.3118    | 7.209     |
# =====================================

# %%
from sklearn.linear_model import Ridge

ridge_final = Ridge(alpha=7.224)
ridge_final.fit(x_train, y_train)

ridge_final_pred = ridge_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, ridge_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(ridge_final.score(x_train, y_train))
print(ridge_final.score(x_test, y_test))
plt.scatter(y_test,ridge_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.017142
# T_SD      0.000693
# dtype: float64
# 0.3408774052393511
# 0.3117654439811434

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Model

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)

dt_pred = dt.predict(x_test)

# 모델 평가
mse = MSE(y_test, dt_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(dt.score(x_train, y_train))
print(dt.score(x_test, y_test))
plt.scatter(y_test,dt_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.000567
# T_SD      0.000073
# dtype: float64
# 1.0
# 0.9519325088472872

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Model

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

rf_pred = rf.predict(x_test)
# 모델 평가
mse = MSE(y_test, rf_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(rf.score(x_train, y_train))
print(rf.score(x_test, y_test))
plt.scatter(y_test,rf_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.000205
# T_SD      0.000020
# dtype: float64
# 0.9963614467864625
# 0.9860269076865498

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(n_estimators):
    
    rf_final = RandomForestRegressor(n_estimators=int(n_estimators), random_state=42)
    rf_final.fit(x_train, y_train)
    
   # Validation
    y_pred = rf_final.predict(x_test)
    acc= rf_final.score(x_test, y_test)
    
    return acc

pbounds = {'n_estimators': (10, 500)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   | n_esti... |
# -------------------------------------
# | 1         | 0.9857    | 214.3     |
# | 2         | 0.9856    | 363.0     |
# | 3         | 0.9782    | 10.06     |
# | 4         | 0.9856    | 158.1     |
# | 5         | 0.986     | 81.91     |
# | 6         | 0.986     | 83.56     |
# | 7         | 0.9859    | 290.2     |
# | 8         | 0.9857    | 442.1     |
# | 9         | 0.9857    | 500.0     |
# | 10        | 0.9856    | 402.7     |
# | 11        | 0.9858    | 253.2     |
# | 12        | 0.9856    | 325.9     |
# | 13        | 0.9857    | 472.2     |
# | 14        | 0.9858    | 125.8     |
# | 15        | 0.9855    | 187.6     |
# | 16        | 0.9859    | 272.4     |
# | 17        | 0.9861    | 107.6     |
# | 18        | 0.9857    | 422.5     |
# | 19        | 0.9857    | 233.8     |
# | 20        | 0.9857    | 307.0     |
# | 21        | 0.9858    | 70.88     |
# | 22        | 0.9856    | 382.0     |
# | 23        | 0.986     | 113.9     |
# | 24        | 0.986     | 100.1     |
# | 25        | 0.9861    | 105.6     |
# | 26        | 0.9856    | 344.4     |
# | 27        | 0.9857    | 457.5     |
# | 28        | 0.9857    | 487.1     |
# | 29        | 0.9856    | 143.0     |
# | 30        | 0.9855    | 173.1     |
# | 31        | 0.9856    | 201.9     |
# | 32        | 0.9859    | 281.4     |
# | 33        | 0.9859    | 262.6     |
# | 34        | 0.9861    | 103.9     |
# | 35        | 0.9856    | 52.69     |
# | 36        | 0.9856    | 392.4     |
# | 37        | 0.9857    | 432.3     |
# | 38        | 0.9857    | 243.3     |
# | 39        | 0.9856    | 316.5     |
# | 40        | 0.9855    | 60.7      |
# | 41        | 0.9862    | 92.0      |
# | 42        | 0.9856    | 412.6     |
# | 43        | 0.9856    | 372.0     |
# | 44        | 0.9857    | 223.9     |
# | 45        | 0.9862    | 93.86     |
# | 46        | 0.986     | 119.5     |
# | 47        | 0.9857    | 297.9     |
# | 48        | 0.9862    | 90.41     |
# | 49        | 0.9862    | 89.65     |
# | 50        | 0.9856    | 335.3     |
# | 51        | 0.9856    | 353.7     |
# | 52        | 0.9853    | 42.06     |
# | 53        | 0.9858    | 134.4     |
# | 54        | 0.9857    | 449.9     |
# | 55        | 0.986     | 76.95     |
# | 56        | 0.9857    | 479.6     |
# | 57        | 0.9861    | 88.32     |
# | 58        | 0.9852    | 31.85     |
# | 59        | 0.9857    | 464.8     |
# | 60        | 0.9855    | 165.5     |
# | 61        | 0.9855    | 150.6     |
# | 62        | 0.9856    | 194.8     |
# | 63        | 0.9857    | 493.8     |
# | 64        | 0.9854    | 180.3     |
# | 65        | 0.9856    | 208.3     |
# | 66        | 0.9858    | 267.5     |
# | 67        | 0.9858    | 248.4     |
# | 68        | 0.9859    | 285.8     |
# | 69        | 0.9857    | 427.4     |
# | 70        | 0.9858    | 258.0     |
# | 71        | 0.9856    | 387.1     |
# | 72        | 0.9857    | 228.9     |
# | 73        | 0.9859    | 276.8     |
# | 74        | 0.9857    | 130.2     |
# | 75        | 0.9857    | 437.4     |
# | 76        | 0.9856    | 407.6     |
# | 77        | 0.9857    | 311.6     |
# | 78        | 0.9862    | 89.78     |
# | 79        | 0.9862    | 89.77     |
# | 80        | 0.9862    | 89.73     |
# | 81        | 0.9862    | 89.8      |
# | 82        | 0.9862    | 89.74     |
# | 83        | 0.9862    | 89.78     |
# | 84        | 0.9862    | 89.71     |
# | 85        | 0.9862    | 89.74     |
# | 86        | 0.9862    | 89.7      |
# | 87        | 0.9862    | 89.82     |
# | 88        | 0.9862    | 89.75     |
# | 89        | 0.9862    | 89.8      |
# | 90        | 0.9862    | 89.72     |
# | 91        | 0.9862    | 89.71     |
# | 92        | 0.9862    | 89.79     |
# | 93        | 0.9862    | 89.76     |
# | 94        | 0.9862    | 89.71     |
# | 95        | 0.9862    | 89.69     |
# | 96        | 0.9862    | 89.79     |
# | 97        | 0.9862    | 89.76     |
# | 98        | 0.9862    | 89.79     |
# | 99        | 0.9862    | 89.7      |
# | 100       | 0.9862    | 89.76     |
# | 101       | 0.9862    | 89.74     |
# | 102       | 0.9862    | 89.72     |
# | 103       | 0.9862    | 89.7      |
# | 104       | 0.9862    | 89.73     |
# | 105       | 0.9862    | 89.76     |
# =====================================

# %%
rf_final = RandomForestRegressor(n_estimators=89, random_state=42)
rf_final.fit(x_train, y_train)

rf_final_pred = rf_final.predict(x_test)
# 모델 평가
mse = MSE(y_test, rf_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(rf_final.score(x_train, y_train))
print(rf_final.score(x_test, y_test))
plt.scatter(y_test,rf_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.00020
# T_SD      0.00002
# dtype: float64
# 0.996412359980736
# 0.9862493069900307

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# ## Model

# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor

svr = MultiOutputRegressor(SVR(kernel='rbf', gamma=0.1, C=0.1))
svr.fit(x_train, y_train)

svr_pred = svr.predict(x_test)
# 모델 평가
mse = MSE(y_test, svr_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(svr.score(x_train, y_train))
print(svr.score(x_test, y_test))
plt.scatter(y_test,svr_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.009517
# T_SD      0.005670
# dtype: float64
# -1.1929878176233082
# -2.029202992906838

# %% [markdown]
# ## Optimize

# %%
def train_acc(gamma, C):
    
    svr_final = MultiOutputRegressor(SVR(kernel='rbf', gamma=gamma, C=C))
    svr_final.fit(x_train, y_train)
    
   # Validation
    y_pred = svr_final.predict(x_test)
    acc= svr_final.score(x_test, y_test)
    
    return acc

pbounds = {'gamma': (0.1, 10), 'C': (0.1, 10)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   |     C     |   gamma   |
# -------------------------------------------------
# | 1         | -2.806    | 4.229     | 7.231     |
# | 2         | -2.741    | 0.1011    | 3.093     |
# | 3         | -2.566    | 1.553     | 1.014     |
# | 4         | -2.728    | 1.944     | 3.521     |
# | 5         | -2.776    | 4.028     | 5.434     |
# | 6         | -0.3652   | 2.958     | 0.1       |
# | 7         | -2.797    | 8.317     | 6.635     |
# | 8         | -2.792    | 1.578     | 6.325     |
# | 9         | -2.81     | 0.9521    | 7.611     |
# | 10        | -0.3909   | 3.381     | 0.1       |
# | 11        | -0.4187   | 5.489     | 0.1       |
# | 12        | -0.4131   | 7.592     | 0.1       |
# | 13        | -2.654    | 6.885     | 1.945     |
# | 14        | -0.4102   | 9.757     | 0.1       |
# | 15        | -2.656    | 10.0      | 1.918     |
# | 16        | -2.838    | 10.0      | 10.0      |
# | 17        | -0.4114   | 8.727     | 0.1       |
# | 18        | -2.838    | 5.787     | 10.0      |
# | 19        | -0.9205   | 6.584     | 0.1377    |
# | 20        | -2.59     | 4.423     | 1.226     |
# | 21        | -2.849    | 0.1       | 10.0      |
# | 22        | -0.3688   | 4.602     | 0.1001    |
# | 23        | -2.415    | 8.175     | 0.5946    |
# | 24        | -2.509    | 3.041     | 0.8034    |
# | 25        | -2.257    | 9.296     | 0.4376    |
# | 26        | -0.441    | 2.933     | 0.1041    |
# | 27        | -1.595    | 5.032     | 0.2137    |
# | 28        | -1.192    | 7.183     | 0.1657    |
# | 29        | -2.768    | 4.668     | 4.931     |
# | 30        | -0.4189   | 5.908     | 0.1       |
# | 31        | -1.35     | 4.161     | 0.1855    |
# | 32        | -2.339    | 5.755     | 0.4964    |
# | 33        | -0.6304   | 9.999     | 0.1132    |
# | 34        | -1.692    | 5.047     | 0.2272    |
# | 35        | -0.4523   | 8.023     | 0.1014    |
# | 36        | -2.408    | 9.984     | 0.5752    |
# | 37        | -2.481    | 6.726     | 0.7185    |
# | 38        | -2.838    | 2.952     | 10.0      |
# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor

svr_final = MultiOutputRegressor(SVR(kernel='rbf', gamma=0.04943, C=3.237))
svr_final.fit(x_train, y_train)

svr_final_pred = svr_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, svr_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

print(svr_final.score(x_train, y_train))
print(svr_final.score(x_test, y_test))
plt.scatter(y_test,svr_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Mean Squared Error: T_mean    0.006821
# T_SD      0.001405
# dtype: float64
# 0.3289839295922875
# 0.16074319760105232

# %% [markdown]
# # Neural Networks

# %% [markdown]
# ## Model

# %%
import tensorflow as tf

# 다중 출력을 다루는 신경망 모델 정의
nn = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
])

# 모델 컴파일
nn.compile(optimizer='adam', loss='mean_squared_error')

# 모델 훈련
nn.fit(x_train, y_train, epochs=50, batch_size=16, validation_split=0.2)

nn_pred = nn.predict(x_test)

# 모델 평가
mse = MSE(y_test, nn_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

# 작을 수록 더 좋음
print(nn.evaluate(x_train, y_train))
print(nn.evaluate(x_test, y_test))

plt.scatter(y_test,nn_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Epoch 1/50
# 53/53 [==============================] - 1s 4ms/step - loss: 0.0775 - val_loss: 0.0355
# Epoch 2/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0333 - val_loss: 0.0252
# Epoch 3/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0180
# Epoch 4/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0116
# Epoch 5/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0073
# Epoch 6/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 7/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 8/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 9/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 10/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 11/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 12/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 13/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 14/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 15/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 16/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 17/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 18/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 19/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 20/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 21/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 22/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 23/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 24/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 25/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 26/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 27/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 28/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 29/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 30/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 31/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 32/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 33/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 34/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 35/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 36/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 38/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 39/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 40/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 41/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 42/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 43/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 44/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 45/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 46/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 47/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 48/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 49/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 50/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0014
# 15/15 [==============================] - 0s 1ms/step
# Mean Squared Error: T_mean    0.001487
# T_SD      0.000252
# dtype: float64
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0011
# 0.0011055434588342905
# 15/15 [==============================] - 0s 1ms/step - loss: 8.6959e-04
# 0.0008695938740856946

# %% [markdown]
# ## Optimize

# %%
from bayes_opt import BayesianOptimization

def train_acc(epochs, batch_size):
    
    # 다중 출력을 다루는 신경망 모델 정의
    nn_final = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
    ])

    # 모델 컴파일
    nn_final.compile(optimizer='adam', loss='mean_squared_error')

    # 모델 훈련
    nn_final.fit(x_train, y_train, epochs=int(epochs), batch_size=int(batch_size), validation_split=0.2, verbose=0)
    
   # Validation
    nn_final_pred = nn_final.predict(x_test)
    acc= nn_final.evaluate(x_test, y_test)
    
    return -acc

pbounds = {'epochs': (10, 100), 'batch_size': (10, 100)} # 범위 설정

optimizer = BayesianOptimization(
    f=train_acc,
    pbounds=pbounds ,
    random_state=1)

optimizer.maximize(init_points=5 , n_iter= 100)
# Out:
# |   iter    |  target   | batch_... |  epochs   |
# -------------------------------------------------
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 9.0253e-04
# | 1         | -0.000902 | 47.53     | 74.83     |
# 15/15 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0012
# | 2         | -0.001163 | 10.01     | 37.21     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0019
# | 3         | -0.001898 | 23.21     | 18.31     |
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0
)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2)  # 출력 레이어의 뉴런이 2개 (다중 출력)
])

# 모델 컴파일
nn_final.compile(optimizer='adam', loss='mean_squared_error')

# 모델 훈련
nn_final.fit(x_train, y_train, epochs=77, batch_size=15, validation_split=0.2)

nn_final_pred = nn_final.predict(x_test)

# 모델 평가
mse = MSE(y_test, nn_final_pred)
print(f'Mean Squared Error: {mse}')

# 결과 시각화 (예시
x = np.linspace(0, 1, 10)

# 작을 수록 더 좋음
print(nn_final.evaluate(x_train, y_train))
print(nn_final.evaluate(x_test, y_test))

plt.scatter(y_test,nn_final_pred)
plt.plot(x, x, '-r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.show()
# Out:
# Epoch 1/77
# 57/57 [==============================] - 1s 3ms/step - loss: 0.0775 - val_loss: 0.0317
# Epoch 2/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0242
# Epoch 3/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0220 - val_loss: 0.0175
# Epoch 4/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0110
# Epoch 5/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0066
# Epoch 6/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 7/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 8/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 9/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 10/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 11/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 12/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 13/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 14/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 15/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 16/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 17/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 18/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 19/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 20/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 21/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 22/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 23/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 24/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 25/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 26/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 27/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 28/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 29/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 30/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 31/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 32/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 33/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 34/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 35/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 36/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 37/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 38/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 39/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 40/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 41/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 42/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 43/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 44/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 45/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 46/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 47/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 48/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 49/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 50/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 51/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 52/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 53/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 54/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 55/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 56/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 57/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.5447e-04 - val_loss: 0.0011
# Epoch 58/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 59/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 9.5463e-04
# Epoch 60/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.2743e-04 - val_loss: 0.0011
# Epoch 61/77
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 62/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.5137e-04 - val_loss: 0.0012
# Epoch 63/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.1275e-04 - val_loss: 9.6800e-04
# Epoch 64/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.0988e-04 - val_loss: 0.0010
# Epoch 65/77
# 57/57 [==============================] - 0s 2ms/step - loss: 8.3162e-04 - val_loss: 8.8043e-04
# Epoch 66/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.8944e-04 - val_loss: 0.0012
# Epoch 67/77
# 57/57 [==============================] - 0s 2ms/step - loss: 8.4257e-04 - val_loss: 0.0010
# Epoch 68/77
# 57/57 [==============================] - 0s 2ms/step - loss: 9.3939e-04 - val_loss: 0.0015
# Epoch 69/77
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 9.6460e-04
# Epoch 70/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.5867e-04 - val_loss: 9.1220e-04
# Epoch 71/77
# 57/57 [==============================] - 0s 2ms/step - loss: 8.5992e-04 - val_loss: 0.0010
# Epoch 72/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.5877e-04 - val_loss: 7.6428e-04
# Epoch 73/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.5508e-04 - val_loss: 8.4316e-04
# Epoch 74/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.3170e-04 - val_loss: 8.1323e-04
# Epoch 75/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.0857e-04 - val_loss: 0.0012
# Epoch 76/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.6231e-04 - val_loss: 8.0953e-04
# Epoch 77/77
# 57/57 [==============================] - 0s 2ms/step - loss: 7.4313e-04 - val_loss: 8.0728e-04
# 15/15 [==============================] - 0s 1ms/step
# Mean Squared Error: T_mean    0.000747
# T_SD      0.000193
# dtype: float64
# 33/33 [==============================] - 0s 1ms/step - loss: 6.5281e-04
# 0.000652805611025542
# 15/15 [==============================] - 0s 1ms/step - loss: 4.6974e-04
# 0.00046974082943052053
